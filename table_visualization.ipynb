# %%
import pandas as pd
import numpy as np
import matplotlib as mpl

# %%
df = pd.DataFrame({
    "strings": ["Adam", "Mike"],
    "ints": [1, 3],
    "floats": [1.123, 1000.23]
})
df
# Out:
#   strings  ints    floats
# 0    Adam     1     1.123
# 1    Mike     3  1000.230

# %%
df.style \
  .format(precision=3, thousands=".", decimal=",") \
  .format_index(str.upper, axis=1) \
  .relabel_index(["row 1", "row 2"], axis=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_81dc0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_81dc0_level0_col0" class="col_heading level0 col0" >STRINGS</th>
#       <th id="T_81dc0_level0_col1" class="col_heading level0 col1" >INTS</th>
#       <th id="T_81dc0_level0_col2" class="col_heading level0 col2" >FLOATS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_81dc0_level0_row0" class="row_heading level0 row0" >row 1</th>
#       <td id="T_81dc0_row0_col0" class="data row0 col0" >Adam</td>
#       <td id="T_81dc0_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_81dc0_row0_col2" class="data row0 col2" >1,123</td>
#     </tr>
#     <tr>
#       <th id="T_81dc0_level0_row1" class="row_heading level0 row1" >row 2</th>
#       <td id="T_81dc0_row1_col0" class="data row1 col0" >Mike</td>
#       <td id="T_81dc0_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_81dc0_row1_col2" class="data row1 col2" >1.000,230</td>
#     </tr>
#   </tbody>
# </table>

# %%
weather_df = pd.DataFrame(np.random.rand(10,2)*5,
                          index=pd.date_range(start="2021-01-01", periods=10),
                          columns=["Tokyo", "Beijing"])

def rain_condition(v):
    if v < 1.75:
        return "Dry"
    elif v < 2.75:
        return "Rain"
    return "Heavy Rain"

def make_pretty(styler):
    styler.set_caption("Weather Conditions")
    styler.format(rain_condition)
    styler.format_index(lambda v: v.strftime("%A"))
    styler.background_gradient(axis=None, vmin=1, vmax=5, cmap="Blues")
    return styler

weather_df
# Out:
#                Tokyo   Beijing
# 2021-01-01  3.474409  1.319598
# 2021-01-02  4.769831  3.423848
# 2021-01-03  4.967436  0.979331
# 2021-01-04  0.067464  3.215232
# 2021-01-05  1.924031  3.391286
# 2021-01-06  2.397675  2.393217
# 2021-01-07  2.676964  1.330557
# 2021-01-08  1.379622  2.890016
# 2021-01-09  3.264430  4.924040
# 2021-01-10  4.987966  1.185502

# %%
weather_df.style.pipe(make_pretty)
# Out:
# <style type="text/css">
# #T_6f074_row0_col0 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_6f074_row0_col1 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_6f074_row1_col0 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_6f074_row1_col1 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_6f074_row2_col0 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_6f074_row2_col1, #T_6f074_row3_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_6f074_row3_col1 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_6f074_row4_col0 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_6f074_row4_col1 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_6f074_row5_col0, #T_6f074_row5_col1 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_6f074_row6_col0 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_6f074_row6_col1 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_6f074_row7_col0 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_6f074_row7_col1 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_6f074_row8_col0 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_6f074_row8_col1 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_6f074_row9_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_6f074_row9_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# </style>
# <table id="T_6f074">
#   <caption>Weather Conditions</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6f074_level0_col0" class="col_heading level0 col0" >Tokyo</th>
#       <th id="T_6f074_level0_col1" class="col_heading level0 col1" >Beijing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f074_level0_row0" class="row_heading level0 row0" >Friday</th>
#       <td id="T_6f074_row0_col0" class="data row0 col0" >Heavy Rain</td>
#       <td id="T_6f074_row0_col1" class="data row0 col1" >Dry</td>
#     </tr>
#     <tr>
#       <th id="T_6f074_level0_row1" class="row_heading level0 row1" >Saturday</th>
#       <td id="T_6f074_row1_col0" class="data row1 col0" >Heavy Rain</td>
#       <td id="T_6f074_row1_col1" class="data row1 col1" >Heavy Rain</td>
#     </tr>
#     <tr>
#       <th id="T_6f074_level0_row2" class="row_heading level0 row2" >Sunday</th>
#       <td id="T_6f074_row2_col0" class="data row2 col0" >Heavy Rain</td>
#       <td id="T_6f074_row2_col1" class="data row2 col1" >Dry</td>
#     </tr>
#     <tr>
#       <th id="T_6f074_level0_row3" class="row_heading level0 row3" >Monday</th>
#       <td id="T_6f074_row3_col0" class="data row3 col0" >Dry</td>
#       <td id="T_6f074_row3_col1" class="data row3 col1" >Heavy Rain</td>
#     </tr>
#     <tr>
#       <th id="T_6f074_level0_row4" class="row_heading level0 row4" >Tuesday</th>
#       <td id="T_6f074_row4_col0" class="data row4 col0" >Rain</td>
#       <td id="T_6f074_row4_col1" class="data row4 col1" >Heavy Rain</td>
#     </tr>
#     <tr>
#       <th id="T_6f074_level0_row5" class="row_heading level0 row5" >Wednesday</th>
#       <td id="T_6f074_row5_col0" class="data row5 col0" >Rain</td>
#       <td id="T_6f074_row5_col1" class="data row5 col1" >Rain</td>
#     </tr>
#     <tr>
#       <th id="T_6f074_level0_row6" class="row_heading level0 row6" >Thursday</th>
#       <td id="T_6f074_row6_col0" class="data row6 col0" >Rain</td>
#       <td id="T_6f074_row6_col1" class="data row6 col1" >Dry</td>
#     </tr>
#     <tr>
#       <th id="T_6f074_level0_row7" class="row_heading level0 row7" >Friday</th>
#       <td id="T_6f074_row7_col0" class="data row7 col0" >Dry</td>
#       <td id="T_6f074_row7_col1" class="data row7 col1" >Heavy Rain</td>
#     </tr>
#     <tr>
#       <th id="T_6f074_level0_row8" class="row_heading level0 row8" >Saturday</th>
#       <td id="T_6f074_row8_col0" class="data row8 col0" >Heavy Rain</td>
#       <td id="T_6f074_row8_col1" class="data row8 col1" >Heavy Rain</td>
#     </tr>
#     <tr>
#       <th id="T_6f074_level0_row9" class="row_heading level0 row9" >Sunday</th>
#       <td id="T_6f074_row9_col0" class="data row9 col0" >Heavy Rain</td>
#       <td id="T_6f074_row9_col1" class="data row9 col1" >Dry</td>
#     </tr>
#   </tbody>
# </table>

# %%
df = pd.DataFrame([[38.0, 2.0, 18.0, 22.0, 21, np.nan],[19, 439, 6, 452, 226,232]],
                  index=pd.Index(['Tumour (Positive)', 'Non-Tumour (Negative)'], name='Actual Label:'),
                  columns=pd.MultiIndex.from_product([['Decision Tree', 'Regression', 'Random'],['Tumour', 'Non-Tumour']], names=['Model:', 'Predicted:']))
df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_dd9a2">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_dd9a2_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_dd9a2_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#       <th id="T_dd9a2_level0_col4" class="col_heading level0 col4" colspan="2">Random</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_dd9a2_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_dd9a2_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_dd9a2_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_dd9a2_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#       <th id="T_dd9a2_level1_col4" class="col_heading level1 col4" >Tumour</th>
#       <th id="T_dd9a2_level1_col5" class="col_heading level1 col5" >Non-Tumour</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Actual Label:</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd9a2_level0_row0" class="row_heading level0 row0" >Tumour (Positive)</th>
#       <td id="T_dd9a2_row0_col0" class="data row0 col0" >38.000000</td>
#       <td id="T_dd9a2_row0_col1" class="data row0 col1" >2.000000</td>
#       <td id="T_dd9a2_row0_col2" class="data row0 col2" >18.000000</td>
#       <td id="T_dd9a2_row0_col3" class="data row0 col3" >22.000000</td>
#       <td id="T_dd9a2_row0_col4" class="data row0 col4" >21</td>
#       <td id="T_dd9a2_row0_col5" class="data row0 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_dd9a2_level0_row1" class="row_heading level0 row1" >Non-Tumour (Negative)</th>
#       <td id="T_dd9a2_row1_col0" class="data row1 col0" >19.000000</td>
#       <td id="T_dd9a2_row1_col1" class="data row1 col1" >439.000000</td>
#       <td id="T_dd9a2_row1_col2" class="data row1 col2" >6.000000</td>
#       <td id="T_dd9a2_row1_col3" class="data row1 col3" >452.000000</td>
#       <td id="T_dd9a2_row1_col4" class="data row1 col4" >226</td>
#       <td id="T_dd9a2_row1_col5" class="data row1 col5" >232.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
s = df.style.format('{:.0f}').hide([('Random', 'Tumour'), ('Random', 'Non-Tumour')], axis="columns")
s
# Out:
# <style type="text/css">
# </style>
# <table id="T_44cab">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_44cab_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_44cab_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_44cab_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_44cab_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_44cab_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_44cab_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Actual Label:</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_44cab_level0_row0" class="row_heading level0 row0" >Tumour (Positive)</th>
#       <td id="T_44cab_row0_col0" class="data row0 col0" >38</td>
#       <td id="T_44cab_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_44cab_row0_col2" class="data row0 col2" >18</td>
#       <td id="T_44cab_row0_col3" class="data row0 col3" >22</td>
#     </tr>
#     <tr>
#       <th id="T_44cab_level0_row1" class="row_heading level0 row1" >Non-Tumour (Negative)</th>
#       <td id="T_44cab_row1_col0" class="data row1 col0" >19</td>
#       <td id="T_44cab_row1_col1" class="data row1 col1" >439</td>
#       <td id="T_44cab_row1_col2" class="data row1 col2" >6</td>
#       <td id="T_44cab_row1_col3" class="data row1 col3" >452</td>
#     </tr>
#   </tbody>
# </table>

# %%
np.random.seed(0)
df2 = pd.DataFrame(np.random.randn(10,4), columns=['A','B','C','D'])
df2.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_e6a95">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6a95_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_e6a95_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_e6a95_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_e6a95_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6a95_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e6a95_row0_col0" class="data row0 col0" >1.764052</td>
#       <td id="T_e6a95_row0_col1" class="data row0 col1" >0.400157</td>
#       <td id="T_e6a95_row0_col2" class="data row0 col2" >0.978738</td>
#       <td id="T_e6a95_row0_col3" class="data row0 col3" >2.240893</td>
#     </tr>
#     <tr>
#       <th id="T_e6a95_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e6a95_row1_col0" class="data row1 col0" >1.867558</td>
#       <td id="T_e6a95_row1_col1" class="data row1 col1" >-0.977278</td>
#       <td id="T_e6a95_row1_col2" class="data row1 col2" >0.950088</td>
#       <td id="T_e6a95_row1_col3" class="data row1 col3" >-0.151357</td>
#     </tr>
#     <tr>
#       <th id="T_e6a95_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e6a95_row2_col0" class="data row2 col0" >-0.103219</td>
#       <td id="T_e6a95_row2_col1" class="data row2 col1" >0.410599</td>
#       <td id="T_e6a95_row2_col2" class="data row2 col2" >0.144044</td>
#       <td id="T_e6a95_row2_col3" class="data row2 col3" >1.454274</td>
#     </tr>
#     <tr>
#       <th id="T_e6a95_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e6a95_row3_col0" class="data row3 col0" >0.761038</td>
#       <td id="T_e6a95_row3_col1" class="data row3 col1" >0.121675</td>
#       <td id="T_e6a95_row3_col2" class="data row3 col2" >0.443863</td>
#       <td id="T_e6a95_row3_col3" class="data row3 col3" >0.333674</td>
#     </tr>
#     <tr>
#       <th id="T_e6a95_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e6a95_row4_col0" class="data row4 col0" >1.494079</td>
#       <td id="T_e6a95_row4_col1" class="data row4 col1" >-0.205158</td>
#       <td id="T_e6a95_row4_col2" class="data row4 col2" >0.313068</td>
#       <td id="T_e6a95_row4_col3" class="data row4 col3" >-0.854096</td>
#     </tr>
#     <tr>
#       <th id="T_e6a95_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e6a95_row5_col0" class="data row5 col0" >-2.552990</td>
#       <td id="T_e6a95_row5_col1" class="data row5 col1" >0.653619</td>
#       <td id="T_e6a95_row5_col2" class="data row5 col2" >0.864436</td>
#       <td id="T_e6a95_row5_col3" class="data row5 col3" >-0.742165</td>
#     </tr>
#     <tr>
#       <th id="T_e6a95_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e6a95_row6_col0" class="data row6 col0" >2.269755</td>
#       <td id="T_e6a95_row6_col1" class="data row6 col1" >-1.454366</td>
#       <td id="T_e6a95_row6_col2" class="data row6 col2" >0.045759</td>
#       <td id="T_e6a95_row6_col3" class="data row6 col3" >-0.187184</td>
#     </tr>
#     <tr>
#       <th id="T_e6a95_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e6a95_row7_col0" class="data row7 col0" >1.532779</td>
#       <td id="T_e6a95_row7_col1" class="data row7 col1" >1.469359</td>
#       <td id="T_e6a95_row7_col2" class="data row7 col2" >0.154947</td>
#       <td id="T_e6a95_row7_col3" class="data row7 col3" >0.378163</td>
#     </tr>
#     <tr>
#       <th id="T_e6a95_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e6a95_row8_col0" class="data row8 col0" >-0.887786</td>
#       <td id="T_e6a95_row8_col1" class="data row8 col1" >-1.980796</td>
#       <td id="T_e6a95_row8_col2" class="data row8 col2" >-0.347912</td>
#       <td id="T_e6a95_row8_col3" class="data row8 col3" >0.156349</td>
#     </tr>
#     <tr>
#       <th id="T_e6a95_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e6a95_row9_col0" class="data row9 col0" >1.230291</td>
#       <td id="T_e6a95_row9_col1" class="data row9 col1" >1.202380</td>
#       <td id="T_e6a95_row9_col2" class="data row9 col2" >-0.387327</td>
#       <td id="T_e6a95_row9_col3" class="data row9 col3" >-0.302303</td>
#     </tr>
#   </tbody>
# </table>

# %%
def style_negative(v, props=''):
    return props if v < 0 else None
s2 = df2.style.map(style_negative, props='color:yellow;')\
              .map(lambda v: 'opacity: 20%;' if (v < 0.3) and (v > -0.3) else None)
s2
# Out:
# <style type="text/css">
# #T_87201_row1_col1, #T_87201_row4_col3, #T_87201_row5_col0, #T_87201_row5_col3, #T_87201_row6_col1, #T_87201_row8_col0, #T_87201_row8_col1, #T_87201_row8_col2, #T_87201_row9_col2, #T_87201_row9_col3 {
#   color: yellow;
# }
# #T_87201_row1_col3, #T_87201_row2_col0, #T_87201_row4_col1, #T_87201_row6_col3 {
#   color: yellow;
#   opacity: 20%;
# }
# #T_87201_row2_col2, #T_87201_row3_col1, #T_87201_row6_col2, #T_87201_row7_col2, #T_87201_row8_col3 {
#   opacity: 20%;
# }
# </style>
# <table id="T_87201">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87201_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_87201_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_87201_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_87201_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87201_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_87201_row0_col0" class="data row0 col0" >1.764052</td>
#       <td id="T_87201_row0_col1" class="data row0 col1" >0.400157</td>
#       <td id="T_87201_row0_col2" class="data row0 col2" >0.978738</td>
#       <td id="T_87201_row0_col3" class="data row0 col3" >2.240893</td>
#     </tr>
#     <tr>
#       <th id="T_87201_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_87201_row1_col0" class="data row1 col0" >1.867558</td>
#       <td id="T_87201_row1_col1" class="data row1 col1" >-0.977278</td>
#       <td id="T_87201_row1_col2" class="data row1 col2" >0.950088</td>
#       <td id="T_87201_row1_col3" class="data row1 col3" >-0.151357</td>
#     </tr>
#     <tr>
#       <th id="T_87201_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_87201_row2_col0" class="data row2 col0" >-0.103219</td>
#       <td id="T_87201_row2_col1" class="data row2 col1" >0.410599</td>
#       <td id="T_87201_row2_col2" class="data row2 col2" >0.144044</td>
#       <td id="T_87201_row2_col3" class="data row2 col3" >1.454274</td>
#     </tr>
#     <tr>
#       <th id="T_87201_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_87201_row3_col0" class="data row3 col0" >0.761038</td>
#       <td id="T_87201_row3_col1" class="data row3 col1" >0.121675</td>
#       <td id="T_87201_row3_col2" class="data row3 col2" >0.443863</td>
#       <td id="T_87201_row3_col3" class="data row3 col3" >0.333674</td>
#     </tr>
#     <tr>
#       <th id="T_87201_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_87201_row4_col0" class="data row4 col0" >1.494079</td>
#       <td id="T_87201_row4_col1" class="data row4 col1" >-0.205158</td>
#       <td id="T_87201_row4_col2" class="data row4 col2" >0.313068</td>
#       <td id="T_87201_row4_col3" class="data row4 col3" >-0.854096</td>
#     </tr>
#     <tr>
#       <th id="T_87201_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_87201_row5_col0" class="data row5 col0" >-2.552990</td>
#       <td id="T_87201_row5_col1" class="data row5 col1" >0.653619</td>
#       <td id="T_87201_row5_col2" class="data row5 col2" >0.864436</td>
#       <td id="T_87201_row5_col3" class="data row5 col3" >-0.742165</td>
#     </tr>
#     <tr>
#       <th id="T_87201_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_87201_row6_col0" class="data row6 col0" >2.269755</td>
#       <td id="T_87201_row6_col1" class="data row6 col1" >-1.454366</td>
#       <td id="T_87201_row6_col2" class="data row6 col2" >0.045759</td>
#       <td id="T_87201_row6_col3" class="data row6 col3" >-0.187184</td>
#     </tr>
#     <tr>
#       <th id="T_87201_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_87201_row7_col0" class="data row7 col0" >1.532779</td>
#       <td id="T_87201_row7_col1" class="data row7 col1" >1.469359</td>
#       <td id="T_87201_row7_col2" class="data row7 col2" >0.154947</td>
#       <td id="T_87201_row7_col3" class="data row7 col3" >0.378163</td>
#     </tr>
#     <tr>
#       <th id="T_87201_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_87201_row8_col0" class="data row8 col0" >-0.887786</td>
#       <td id="T_87201_row8_col1" class="data row8 col1" >-1.980796</td>
#       <td id="T_87201_row8_col2" class="data row8 col2" >-0.347912</td>
#       <td id="T_87201_row8_col3" class="data row8 col3" >0.156349</td>
#     </tr>
#     <tr>
#       <th id="T_87201_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_87201_row9_col0" class="data row9 col0" >1.230291</td>
#       <td id="T_87201_row9_col1" class="data row9 col1" >1.202380</td>
#       <td id="T_87201_row9_col2" class="data row9 col2" >-0.387327</td>
#       <td id="T_87201_row9_col3" class="data row9 col3" >-0.302303</td>
#     </tr>
#   </tbody>
# </table>

# %%
def highlight_max(s, props=''):
    return np.where(s == np.nanmax(s.values), props, '')
s2.apply(highlight_max, props='color:white;background-color:darkblue', axis=0)
# Out:
# <style type="text/css">
# #T_87201_row0_col2, #T_87201_row0_col3, #T_87201_row6_col0, #T_87201_row7_col1 {
#   color: white;
#   background-color: darkblue;
# }
# #T_87201_row1_col1, #T_87201_row4_col3, #T_87201_row5_col0, #T_87201_row5_col3, #T_87201_row6_col1, #T_87201_row8_col0, #T_87201_row8_col1, #T_87201_row8_col2, #T_87201_row9_col2, #T_87201_row9_col3 {
#   color: yellow;
# }
# #T_87201_row1_col3, #T_87201_row2_col0, #T_87201_row4_col1, #T_87201_row6_col3 {
#   color: yellow;
#   opacity: 20%;
# }
# #T_87201_row2_col2, #T_87201_row3_col1, #T_87201_row6_col2, #T_87201_row7_col2, #T_87201_row8_col3 {
#   opacity: 20%;
# }
# </style>
# <table id="T_87201">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87201_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_87201_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_87201_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_87201_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87201_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_87201_row0_col0" class="data row0 col0" >1.764052</td>
#       <td id="T_87201_row0_col1" class="data row0 col1" >0.400157</td>
#       <td id="T_87201_row0_col2" class="data row0 col2" >0.978738</td>
#       <td id="T_87201_row0_col3" class="data row0 col3" >2.240893</td>
#     </tr>
#     <tr>
#       <th id="T_87201_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_87201_row1_col0" class="data row1 col0" >1.867558</td>
#       <td id="T_87201_row1_col1" class="data row1 col1" >-0.977278</td>
#       <td id="T_87201_row1_col2" class="data row1 col2" >0.950088</td>
#       <td id="T_87201_row1_col3" class="data row1 col3" >-0.151357</td>
#     </tr>
#     <tr>
#       <th id="T_87201_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_87201_row2_col0" class="data row2 col0" >-0.103219</td>
#       <td id="T_87201_row2_col1" class="data row2 col1" >0.410599</td>
#       <td id="T_87201_row2_col2" class="data row2 col2" >0.144044</td>
#       <td id="T_87201_row2_col3" class="data row2 col3" >1.454274</td>
#     </tr>
#     <tr>
#       <th id="T_87201_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_87201_row3_col0" class="data row3 col0" >0.761038</td>
#       <td id="T_87201_row3_col1" class="data row3 col1" >0.121675</td>
#       <td id="T_87201_row3_col2" class="data row3 col2" >0.443863</td>
#       <td id="T_87201_row3_col3" class="data row3 col3" >0.333674</td>
#     </tr>
#     <tr>
#       <th id="T_87201_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_87201_row4_col0" class="data row4 col0" >1.494079</td>
#       <td id="T_87201_row4_col1" class="data row4 col1" >-0.205158</td>
#       <td id="T_87201_row4_col2" class="data row4 col2" >0.313068</td>
#       <td id="T_87201_row4_col3" class="data row4 col3" >-0.854096</td>
#     </tr>
#     <tr>
#       <th id="T_87201_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_87201_row5_col0" class="data row5 col0" >-2.552990</td>
#       <td id="T_87201_row5_col1" class="data row5 col1" >0.653619</td>
#       <td id="T_87201_row5_col2" class="data row5 col2" >0.864436</td>
#       <td id="T_87201_row5_col3" class="data row5 col3" >-0.742165</td>
#     </tr>
#     <tr>
#       <th id="T_87201_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_87201_row6_col0" class="data row6 col0" >2.269755</td>
#       <td id="T_87201_row6_col1" class="data row6 col1" >-1.454366</td>
#       <td id="T_87201_row6_col2" class="data row6 col2" >0.045759</td>
#       <td id="T_87201_row6_col3" class="data row6 col3" >-0.187184</td>
#     </tr>
#     <tr>
#       <th id="T_87201_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_87201_row7_col0" class="data row7 col0" >1.532779</td>
#       <td id="T_87201_row7_col1" class="data row7 col1" >1.469359</td>
#       <td id="T_87201_row7_col2" class="data row7 col2" >0.154947</td>
#       <td id="T_87201_row7_col3" class="data row7 col3" >0.378163</td>
#     </tr>
#     <tr>
#       <th id="T_87201_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_87201_row8_col0" class="data row8 col0" >-0.887786</td>
#       <td id="T_87201_row8_col1" class="data row8 col1" >-1.980796</td>
#       <td id="T_87201_row8_col2" class="data row8 col2" >-0.347912</td>
#       <td id="T_87201_row8_col3" class="data row8 col3" >0.156349</td>
#     </tr>
#     <tr>
#       <th id="T_87201_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_87201_row9_col0" class="data row9 col0" >1.230291</td>
#       <td id="T_87201_row9_col1" class="data row9 col1" >1.202380</td>
#       <td id="T_87201_row9_col2" class="data row9 col2" >-0.387327</td>
#       <td id="T_87201_row9_col3" class="data row9 col3" >-0.302303</td>
#     </tr>
#   </tbody>
# </table>
